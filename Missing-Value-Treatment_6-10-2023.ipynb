# %% [markdown]
# ### titanic.csv

# %%
import pandas as pd

# %%
df=pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
missing_values = df.isna()
missing_values
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
missing_count = df.isna().sum()
missing_count
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
x=df["Age"].median()
df["Age"].fillna(x,inplace=True)

# %%
x=df["Cabin"].mode()[0]
df["Cabin"].fillna(x,inplace=True)

# %%
x=df["Embarked"].mode()[0]
x
# Out:
# 'S'

# %%
df["Embarked"].fillna(x,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
missing_count = df.isna().sum()
missing_count
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# ### airports.csv

# %%
df=pd.read_csv("airports .csv")
df
# Out:
#            id    ident           type                       name  \
# 0        6523      00A       heliport          Total RF Heliport
# 1      323361     00AA  small_airport       Aero B Ranch Airport
# 2        6524     00AK  small_airport               Lowell Field
# 3        6525     00AL  small_airport               Epps Airpark
# 4      506791     00AN  small_airport       Katmai Lodge Airport
# ...       ...      ...            ...                        ...
# 76362   46378  ZZ-0001       heliport            Sealand Helipad
# 76363  307326  ZZ-0002  small_airport  Glorioso Islands Airstrip
# 76364  346788  ZZ-0003  small_airport      Fainting Goat Airport
# 76365  342102     ZZZW         closed     Scandium City Heliport
# 76366  313629     ZZZZ  small_airport     Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070985     -74.933689          11.0       NaN          US
# ...

# %%
df.columns
# Out:
# Index(['id', 'ident', 'type', 'name', 'latitude_deg', 'longitude_deg',
#        'elevation_ft', 'continent', 'iso_country', 'iso_region',
#        'municipality', 'scheduled_service', 'gps_code', 'iata_code',
#        'local_code', 'home_link', 'wikipedia_link', 'keywords'],
#       dtype='object')

# %%
df["keywords"].value_counts()
# Out:
# keywords
# Mukho                            50
# Cheonmi-ri                       18
# Manhattan, New York City, NYC     7
# Victorian Aerial Fire Bases       5
# Oil & Gas, NOVATEK                5
#                                  ..
# FB00                              1
# FB04                              1
# FB03                              1
# FB08                              1
# SATSUMA,IWOJIMA,RJX7              1
# Name: count, Length: 16662, dtype: int64

# %%
missing_count = df.isna().sum()
missing_count
# Out:
# id                       0
# ident                    0
# type                     0
# name                     0
# latitude_deg             0
# longitude_deg            0
# elevation_ft         14398
# continent            36995
# iso_country            259
# iso_region               0
# municipality          5050
# scheduled_service        0
# gps_code             35022
# iata_code            67478
# local_code           43575
# home_link            72673
# wikipedia_link       65332
# keywords             59329
# dtype: int64

# %%
x=df["elevation_ft"].mean()
df["elevation_ft"].fillna(x,inplace=True)

# %%
x=df["continent"].mode()[0]
df["continent"].fillna(x,inplace=True)

# %%
x=df["iso_country"].mode()[0]
df["iso_country"].fillna(x,inplace=True)

# %%
x=df["municipality"].mode()[0]
df["municipality"].fillna(x,inplace=True)

# %%
df.drop('home_link',axis=1,inplace=True)
df
# Out:
#            id    ident           type                       name  \
# 0        6523      00A       heliport          Total RF Heliport
# 1      323361     00AA  small_airport       Aero B Ranch Airport
# 2        6524     00AK  small_airport               Lowell Field
# 3        6525     00AL  small_airport               Epps Airpark
# 4      506791     00AN  small_airport       Katmai Lodge Airport
# ...       ...      ...            ...                        ...
# 76362   46378  ZZ-0001       heliport            Sealand Helipad
# 76363  307326  ZZ-0002  small_airport  Glorioso Islands Airstrip
# 76364  346788  ZZ-0003  small_airport      Fainting Goat Airport
# 76365  342102     ZZZW         closed     Scandium City Heliport
# 76366  313629     ZZZZ  small_airport     Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070985     -74.933689          11.0        AS          US
# ...

# %%
df.drop('wikipedia_link',axis=1,inplace=True)
df
# Out:
#            id    ident           type                       name  \
# 0        6523      00A       heliport          Total RF Heliport
# 1      323361     00AA  small_airport       Aero B Ranch Airport
# 2        6524     00AK  small_airport               Lowell Field
# 3        6525     00AL  small_airport               Epps Airpark
# 4      506791     00AN  small_airport       Katmai Lodge Airport
# ...       ...      ...            ...                        ...
# 76362   46378  ZZ-0001       heliport            Sealand Helipad
# 76363  307326  ZZ-0002  small_airport  Glorioso Islands Airstrip
# 76364  346788  ZZ-0003  small_airport      Fainting Goat Airport
# 76365  342102     ZZZW         closed     Scandium City Heliport
# 76366  313629     ZZZZ  small_airport     Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070985     -74.933689          11.0        AS          US
# ...

# %%
df['keywords'].fillna('UnKnown',inplace=True)

# %%
df['gps_code'].fillna('UnKnown')
# Out:
# 0           K00A
# 1           00AA
# 2           00AK
# 3           00AL
# 4           00AN
#           ...
# 76362    UnKnown
# 76363    UnKnown
# 76364       87TX
# 76365    UnKnown
# 76366       RJX7
# Name: gps_code, Length: 76367, dtype: object

# %%
df['gps_code'].value_counts()
# Out:
# gps_code
# K00A    1
# OYAT    1
# P09     1
# KP15    1
# P18     1
#        ..
# CYHY    1
# CYHZ    1
# CYIB    1
# CYID    1
# RJX7    1
# Name: count, Length: 41345, dtype: int64

# %%
missing_count = df.isna().sum()
missing_count
# Out:
# id                       0
# ident                    0
# type                     0
# name                     0
# latitude_deg             0
# longitude_deg            0
# elevation_ft             0
# continent                0
# iso_country              0
# iso_region               0
# municipality             0
# scheduled_service        0
# gps_code             35022
# iata_code            67478
# local_code           43575
# keywords                 0
# dtype: int64

# %% [markdown]
# ### pakwheels used cars.csv

# %%
df=pd.read_csv('pakwheels_used_cars.csv')
df
# Out:
#         ad_ref  assembly       body     ad_city                color  \
# 0      7927285  Imported        Van      Lahore          Pearl White
# 1      7679303  Imported  Hatchback      Lahore                 Grey
# 2      7915479       NaN      Sedan      Lahore          Super white
# 3      7918380       NaN      Sedan      Lahore  Crystal Black Pearl
# 4      7676167  Imported        MPV      Lahore               Silver
# ...        ...       ...        ...         ...                  ...
# 77232  7727137  Imported  Micro Van  Gujranwala                Black
# 77233  7733253       NaN      Sedan     Karachi          Super White
# 77234  7719906  Imported  Micro Van  Gujranwala               Silver
# 77235  7627128       NaN      Sedan   Islamabad                 Blue
# 77236  7758009       NaN      Sedan     Karachi        Taffeta White
#
#        engine_cc fuel_type    make  mileage    model     registered  \
# 0         2000.0    Hybrid  Nissan   124000   Serena  Un-Registered
# ...

# %%
missing_count = df.isna().sum()
missing_count
# Out:
# ad_ref              0
# assembly        53261
# body             8865
# ad_city             0
# color            1510
# engine_cc           2
# fuel_type         934
# make                0
# mileage             0
# model               0
# registered          0
# transmission        0
# year             4721
# price             649
# dtype: int64

# %%
x=df["assembly"].mode()[0]
df["assembly"].fillna(x,inplace=True)

# %%
df['body'].value_counts()
# Out:
# body
# Sedan                29951
# Hatchback            24868
# SUV                   5001
# Crossover             2135
# Mini Van              1324
# Compact sedan          771
# MPV                    764
# Double Cabin           751
# Van                    735
# Pick Up                520
# Micro Van              516
# Compact SUV            462
# Station Wagon          231
# Coupe                   89
# Truck                   85
# High Roof               75
# Convertible             45
# Single Cabin            25
# Off-Road Vehicles       12
# Mini Vehicles            8
# Compact hatchback        4
# Name: count, dtype: int64

# %%
x=df["body"].mode()[0]
df["body"].fillna(x,inplace=True)

# %%
df['color'].value_counts()
# Out:
# color
# White                       21324
# Silver                       8116
# Black                        6962
# Grey                         4164
# Solid White                  4070
#                             ...
# Crimson Red                     1
# Sun Gold Black                  1
# Premium Silver Metallic         1
# Florett Silver Metallic         1
# Atlantis Turquoise Pearl        1
# Name: count, Length: 386, dtype: int64

# %%
x=df["color"].mode()[0]
df["color"].fillna(x,inplace=True)

# %%
x=df["engine_cc"].mean()
df["engine_cc"].fillna(x,inplace=True)

# %%
df['fuel_type'].value_counts()
# Out:
# fuel_type
# Petrol    70028
# Diesel     3444
# Hybrid     2831
# Name: count, dtype: int64

# %%
x=df["fuel_type"].mode()[0]
df["fuel_type"].fillna(x,inplace=True)

# %%
x=df["year"].mode()[0]
df["year"].fillna(x,inplace=True)

# %%
df['price'].value_counts()
# Out:
# price
# 2500000.0     691
# 3500000.0     660
# 4500000.0     623
# 3000000.0     576
# 4000000.0     568
#              ...
# 8310000.0       1
# 80500000.0      1
# 1098000.0       1
# 25700000.0      1
# 1826000.0       1
# Name: count, Length: 2290, dtype: int64

# %%
x=df["price"].mean()
df["price"].fillna(x,inplace=True)

# %%
df
# Out:
#         ad_ref  assembly       body     ad_city                color  \
# 0      7927285  Imported        Van      Lahore          Pearl White
# 1      7679303  Imported  Hatchback      Lahore                 Grey
# 2      7915479  Imported      Sedan      Lahore          Super white
# 3      7918380  Imported      Sedan      Lahore  Crystal Black Pearl
# 4      7676167  Imported        MPV      Lahore               Silver
# ...        ...       ...        ...         ...                  ...
# 77232  7727137  Imported  Micro Van  Gujranwala                Black
# 77233  7733253  Imported      Sedan     Karachi          Super White
# 77234  7719906  Imported  Micro Van  Gujranwala               Silver
# 77235  7627128  Imported      Sedan   Islamabad                 Blue
# 77236  7758009  Imported      Sedan     Karachi        Taffeta White
#
#        engine_cc fuel_type    make  mileage    model     registered  \
# 0         2000.0    Hybrid  Nissan   124000   Serena  Un-Registered
# ...

# %%
missing_count = df.isna().sum()
missing_count
# Out:
# ad_ref          0
# assembly        0
# body            0
# ad_city         0
# color           0
# engine_cc       0
# fuel_type       0
# make            0
# mileage         0
# model           0
# registered      0
# transmission    0
# year            0
# price           0
# dtype: int64
